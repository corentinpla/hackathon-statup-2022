# %%
import pandas as pd
tab=pd.read_csv('Transfos_data.csv',';')
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
tab
# Out:
#                                     ID        0-        1-        2-  \
# 0     LibriSpeech/6000-55211-0000.flac  0.487979  0.573403  0.643028
# 1     LibriSpeech/5456-24741-0000.flac  0.993512  0.654813  0.156483
# 2     LibriSpeech/118-121721-0000.flac  1.706395  1.795145  1.178941
# 3    LibriSpeech/2514-149482-0000.flac  0.169516  0.337656  0.375536
# 4     LibriSpeech/3235-11599-0000.flac  0.083555  0.113971  0.118024
# ..                                 ...       ...       ...       ...
# 246    LibriSpeech/2836-5354-0000.flac  0.056547  0.064061  0.074212
# 247   LibriSpeech/6836-61803-0000.flac  0.512336  0.829886  0.760409
# 248  LibriSpeech/8797-294123-0000.flac  0.406430  0.798374  0.745919
# 249   LibriSpeech/201-122255-0000.flac  0.066586  0.190153  0.330464
# 250  LibriSpeech/4813-248638-0000.flac  0.098663  0.210715  0.275207
#
#            3-        4-        5-        6-        7-        8-  ...  \
# 0    0.861230  0.802667  0.455865  0.593162  0.725305  0.401430  ...
# 1    0.120092  0.144239  0.191182  0.378076  1.174657  3.641712  ...
# 2    0.680313  0.640329  0.735249  0.583738  0.308485  0.258353  ...
# 3    0.272153  0.300265  0.413113  0.771782  2.101925  6.155569  ...
# 4    0.118629  0.126105  0.138086  0.143401  0.145098  0.146040  ...
# ..        ...       ...       ...       ...       ...       ...  ...
# 246  0.088231  0.104189  0.112989  0.122389  0.133390  0.136947  ...
# 247  0.502847  0.359178  0.416297  0.627790  1.118219  2.039134  ...
# 248  0.492319  0.315400  0.261408  0.219777  0.306564  0.643043  ...
# 249  0.317026  0.245592  0.302157  0.294228  0.170055  0.459680  ...
# 250  0.224271  0.177610  0.192415  0.279831  0.732497  1.753399  ...
#
#             1017-         1018-         1019-         1020-         1021-  \
# 0    4.142674e-07  4.451115e-07  4.021785e-07  3.906157e-07  3.961581e-07
# 1    2.021340e-07  2.097324e-07  2.240977e-07  2.061528e-07  2.074569e-07
# 2    5.108737e-07  5.048265e-07  5.038774e-07  4.893439e-07  5.320143e-07
# 3    4.100485e-07  4.065755e-07  3.723731e-07  3.844152e-07  3.937767e-07
# 4    3.338876e-07  3.431815e-07  3.567918e-07  3.723993e-07  3.764237e-07
# ..            ...           ...           ...           ...           ...
# 246  4.188634e-07  4.275131e-07  4.225749e-07  4.046080e-07  4.066844e-07
# 247  2.976676e-07  3.339675e-07  3.318553e-07  3.028831e-07  2.880802e-07
# 248  2.416342e-07  2.413987e-07  2.793072e-07  2.679701e-07  2.574407e-07
# 249  3.587306e-07  3.647908e-07  3.636322e-07  3.444328e-07  3.838390e-07
# 250  3.188541e-07  3.382221e-07  3.269635e-07  3.368214e-07  3.487721e-07
#
#             1022-         1023-         1024-  SEXE-  ORIGIN-
# 0    3.951907e-07  4.149605e-07  4.003124e-07      1    TRAIN
# 1    1.986923e-07  1.878496e-07  1.653326e-07      0    TRAIN
# 2    5.484421e-07  5.049845e-07  4.645760e-07      0    TRAIN
# 3    3.837614e-07  3.951100e-07  3.719376e-07      0    TRAIN
# 4    3.565494e-07  3.458508e-07  3.151123e-07      1    TRAIN
# ..            ...           ...           ...    ...      ...
# 246  4.154895e-07  4.148661e-07  3.760980e-07      1     TEST
# 247  2.751875e-07  2.723736e-07  2.413219e-07      0     TEST
# 248  2.752014e-07  2.684458e-07  2.226037e-07      0     TEST
# 249  3.915040e-07  3.787805e-07  3.491598e-07      0     TEST
# 250  3.174392e-07  2.945681e-07  2.579335e-07      0     TEST
#
# [251 rows x 1028 columns]

# %%
prov=tab.groupby('SEXE-').mean()

# %%
L=[]
for i in range(1,prov.columns.shape[0]):
        calc=prov[tab.columns[i]].iloc[0]/prov[prov.columns[i]].iloc[1]
        #print(prov[tab.columns[i]].iloc[0]/prov[prov.columns[i]].iloc[1])
        if calc>0.95 and calc<1.05:
            L.append(i)
            print(i,len(L))
# Out:
# 6 1
# 22 2
# 49 3
# 50 4
# 53 5
# 54 6
# 61 7
# 62 8
# 63 9
# 99 10
# 100 11
# 101 12
# 102 13
# 103 14
# 104 15
# 112 16
# 113 17
# 150 18
# 155 19
# 156 20
# 157 21
# 158 22
# 159 23
# 160 24
# 161 25
# 162 26
# 163 27
# 164 28
# 196 29
# 197 30
# 198 31
# 199 32
# 200 33
# 201 34
# 202 35
# 203 36
# 204 37
# 205 38
# 245 39
# 246 40
# 247 41
# 248 42
# 249 43
# 250 44
# 299 45
# 302 46
# 303 47
# 304 48
# 305 49
# 306 50
# 307 51
# 333 52
# 334 53
# 335 54
# 336 55
# 337 56
# 338 57
# 339 58
# 340 59
# 341 60
# 342 61
