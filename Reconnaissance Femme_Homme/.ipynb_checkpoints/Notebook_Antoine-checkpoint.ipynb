# %%
import pandas as pd
from librosa.feature import mfcc
import librosa

# %%
df = pd.read_excel('SPEAKER.xls')
df
# Out:
#       ID    SEX   SUBSET             MINUTES               NAME
# 0       14   F    train-clean-360      25.03    Kristin LeMoine
# 1       16   F    train-clean-360      25.11     Alys AtteWater
# 2       17   M    train-clean-360      25.04     Gord Mackenzie
# 3       19   F    train-clean-100      25.19   Kara Shallenberg
# 4       20   F    train-other-500      30.07             Gesine
# ...    ...  ...                 ...      ...                ...
# 2479  8975   F    train-clean-100      25.11        Daisy Flaim
# 2480  9000   M    train-other-500      27.26    Ramon Escamilla
# 2481  9022   F    train-clean-360      25.17           Claire M
# 2482  9023   F    train-clean-360      25.19       P. J. Morgan
# 2483  9026   F    train-clean-360      21.75       Tammy Porter
#
# [2484 rows x 5 columns]

# %%
y, sr = librosa.load('LibriSpeech/19-198-0000.flac')
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)

# %%
librosa.feature.mfcc(y=y, sr=sr).shape
# Out:
# (20, 85)

# %%
librosa.feature.mfcc(y=y, sr=sr, hop_length=1024, htk=True)
# Out:
# array([[-4.95858093e+02, -4.72281158e+02, -4.68843933e+02,
#         -4.69801483e+02, -4.69645294e+02, -4.70052063e+02,
#         -4.68950165e+02, -4.70442261e+02, -4.66413422e+02,
#         -4.69826843e+02, -4.73937439e+02, -4.55825470e+02,
#         -4.47188843e+02, -3.65581421e+02, -2.91227783e+02,
#         -2.21758545e+02, -2.27103317e+02, -2.31385223e+02,
#         -2.53907822e+02, -2.60563049e+02, -2.19976028e+02,
#         -2.19633102e+02, -2.20951355e+02, -2.67328003e+02,
#         -2.83777100e+02, -2.91185059e+02, -2.43523163e+02,
#         -2.99952271e+02, -2.24877274e+02, -1.79804611e+02,
#         -2.03898239e+02, -1.91680405e+02, -3.31932281e+02,
#         -2.67257050e+02, -2.98690796e+02, -3.40274750e+02,
#         -3.52252380e+02, -3.69958221e+02, -4.04524963e+02,
#         -4.26853577e+02, -4.50881592e+02, -4.58750061e+02,
#         -4.66380371e+02],
#        [ 1.08994713e+02,  1.07953766e+02,  1.13422295e+02,
# ...
