# %%
import pandas as pd
import numpy as np
import librosa, librosa.display
import matplotlib.pyplot as plt
import os

# %%
tab=pd.read_excel('SPEAKER.xls')
# Out:
# 8       26
# 9       27
# 32      60
# 41      78
# 68     118
# 88     163
# 99     196
# 103    201
# 122    229
# 124    233
# Name: ID, dtype: int64

# %%
len(X2['ID'])
# Out:
# 10

# %%
def FFT(ID,FH):
    signal, sr=librosa.load(ID)
    # Creating a Discrete-Fourier Transform with our FFT algorithm
    fast_fourier_transf = np.fft.fft(signal,n=300)
    # Magnitudes indicate the contribution of each frequency
    magnitude = np.abs(fast_fourier_transf)
    # mapping the magnitude to the relative frequency bins
    frequency = np.linspace(0, sr, len(magnitude))
    # We only need the first half of the magnitude and frequency
    left_mag = magnitude[:int(len(magnitude)/2)]
    data=pd.DataFrame([left_mag.tolist()])
    data['ID']=ID
    data['SEXE']=FH
    return(data)

# %%
data=FFT(tab['Name'].iloc[0],tab['SEX'].iloc[0])
for i in range(1,len(tab['ID'])):
    data=data.append(FFT(tab['Name'].iloc[i],tab['SEX'].iloc[i]))
data=data.set_index('ID')

# %%
data
# Out:
#                                          0         1         2         3  \
# ID
# LibriSpeech/26-495-0000.flac      0.090510  0.249425  0.086462  0.064017
# LibriSpeech/27-123349-0000.flac   0.127780  0.098869  0.017245  0.053908
# LibriSpeech/60-121082-0000.flac   0.013766  0.060583  0.018061  0.037142
# LibriSpeech/78-368-0000.flac      0.025730  0.190359  0.023830  0.019453
# LibriSpeech/118-121721-0000.flac  0.014289  0.214907  0.064942  0.082993
# LibriSpeech/163-121908-0000.flac  0.962306  1.596614  0.267788  0.037124
# LibriSpeech/196-122150-0000.flac  0.006062  0.016489  0.015109  0.006151
# LibriSpeech/201-122255-0000.flac  0.005757  0.013039  0.006332  0.005077
# LibriSpeech/229-130880-0000.flac  1.480776  0.064009  0.072326  0.209071
# LibriSpeech/233-134440-0000.flac  1.637405  0.818341  0.189645  0.164706
#
#                                          4         5         6         7  \
# ID
# LibriSpeech/26-495-0000.flac      0.058153  0.021667  0.036942  0.027438
# LibriSpeech/27-123349-0000.flac   0.028970  0.011018  0.020200  0.019685
# LibriSpeech/60-121082-0000.flac   0.021395  0.011735  0.012851  0.020574
# LibriSpeech/78-368-0000.flac      0.011910  0.011545  0.012344  0.009828
# LibriSpeech/118-121721-0000.flac  0.030620  0.055731  0.075801  0.044602
# LibriSpeech/163-121908-0000.flac  0.123904  0.068715  0.048257  0.023296
# LibriSpeech/196-122150-0000.flac  0.004507  0.007973  0.005057  0.009114
# LibriSpeech/201-122255-0000.flac  0.004968  0.008482  0.013150  0.005198
# LibriSpeech/229-130880-0000.flac  0.263113  0.099650  0.076168  0.107054
# LibriSpeech/233-134440-0000.flac  0.106326  0.076568  0.086577  0.109966
#
#                                          8         9  ...       141       142  \
# ID                                                    ...
# LibriSpeech/26-495-0000.flac      0.021488  0.049888  ...  0.000516  0.000496
# LibriSpeech/27-123349-0000.flac   0.014253  0.008480  ...  0.000191  0.000190
# LibriSpeech/60-121082-0000.flac   0.054190  0.028848  ...  0.000380  0.000380
# LibriSpeech/78-368-0000.flac      0.006321  0.014269  ...  0.000049  0.000047
# LibriSpeech/118-121721-0000.flac  0.027862  0.021802  ...  0.001072  0.001070
# LibriSpeech/163-121908-0000.flac  0.029866  0.014702  ...  0.001137  0.001127
# LibriSpeech/196-122150-0000.flac  0.002956  0.001158  ...  0.000082  0.000082
# LibriSpeech/201-122255-0000.flac  0.012294  0.005100  ...  0.000042  0.000041
# LibriSpeech/229-130880-0000.flac  0.111952  0.050156  ...  0.001267  0.001266
# LibriSpeech/233-134440-0000.flac  0.041156  0.025762  ...  0.004115  0.004110
#
#                                        143       144       145       146  \
# ID
# LibriSpeech/26-495-0000.flac      0.000479  0.000464  0.000451  0.000440
# LibriSpeech/27-123349-0000.flac   0.000190  0.000189  0.000188  0.000188
# LibriSpeech/60-121082-0000.flac   0.000379  0.000379  0.000379  0.000379
# LibriSpeech/78-368-0000.flac      0.000046  0.000045  0.000044  0.000044
# LibriSpeech/118-121721-0000.flac  0.001068  0.001066  0.001065  0.001064
# LibriSpeech/163-121908-0000.flac  0.001118  0.001111  0.001105  0.001099
# LibriSpeech/196-122150-0000.flac  0.000082  0.000081  0.000081  0.000081
# LibriSpeech/201-122255-0000.flac  0.000041  0.000041  0.000040  0.000040
# LibriSpeech/229-130880-0000.flac  0.001265  0.001264  0.001263  0.001263
# LibriSpeech/233-134440-0000.flac  0.004106  0.004103  0.004100  0.004098
#
#                                        147       148       149  SEXE
# ID
# LibriSpeech/26-495-0000.flac      0.000431  0.000425  0.000422    M
# LibriSpeech/27-123349-0000.flac   0.000188  0.000187  0.000187    M
# LibriSpeech/60-121082-0000.flac   0.000378  0.000378  0.000378    M
# LibriSpeech/78-368-0000.flac      0.000043  0.000043  0.000043    M
# LibriSpeech/118-121721-0000.flac  0.001063  0.001062  0.001062    M
# LibriSpeech/163-121908-0000.flac  0.001095  0.001093  0.001091    M
# LibriSpeech/196-122150-0000.flac  0.000081  0.000081  0.000081    M
# LibriSpeech/201-122255-0000.flac  0.000040  0.000040  0.000040    M
# LibriSpeech/229-130880-0000.flac  0.001262  0.001262  0.001262    M
# LibriSpeech/233-134440-0000.flac  0.004096  0.004095  0.004094    M
#
# [10 rows x 151 columns]

# %%
X=tab['ID']
y=tab['SEX']
tab['Train_Test']=np.nan

# %%
tab[tab['ID'].isin(X_train['ID'].to_list())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15332/4118501203.py in <module>
# ----> 1 tab[tab['ID'].isin(X_train['ID'].to_list())]
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.model_selection import train_test_split

# %%
X=tab.drop(columns=['SEX'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
import torch
import torchaudio
import torchaudio.functional as F
import torchaudio.transforms as T

# %%
import librosa, librosa.display
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
signal, sr=librosa.load("LibriSpeech/19-198-0000.flac")

# %%
signal

# %%
# Creating a Discrete-Fourier Transform with our FFT algorithm
fast_fourier_transf = np.fft.fft(signal,n=300)
# Magnitudes indicate the contribution of each frequency
magnitude = np.abs(fast_fourier_transf)
# mapping the magnitude to the relative frequency bins
frequency = np.linspace(0, sr, len(magnitude))
# We only need the first half of the magnitude and frequency
left_mag = magnitude[:int(len(magnitude)/2)]
left_freq = frequency[:int(len(frequency)/2)]
plt.plot(left_freq, left_mag)
plt.title('Discrete-Fourier Transform', fontdict=dict(size=15))
plt.xlabel('Frequency', fontdict=dict(size=12))
plt.ylabel('Magnitude', fontdict=dict(size=12))
plt.show()

# %%
data
