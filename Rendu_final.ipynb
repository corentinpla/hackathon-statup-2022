# %%
# !pip install Resemblyzer
# !pip install inaSpeechSegmenter 
# !pip install spectralcluster
# !pip install pydub

from resemblyzer import preprocess_wav, VoiceEncoder
from pathlib import Path
from inaSpeechSegmenter import Segmenter
from inaSpeechSegmenter.export_funcs import seg2csv, seg2textgrid
from spectralcluster import SpectralClusterer
from spectralcluster import RefinementOptions
from spectralcluster import ThresholdType
from spectralcluster import ICASSP2018_REFINEMENT_SEQUENCE
from resemblyzer.audio import sampling_rate
from pydub import AudioSegment
import numpy as np
import os
import joblib
import librosa
import pandas as pd
# Out:
# Requirement already satisfied: Resemblyzer in c:\users\paul\anaconda3\lib\site-packages (0.1.1.dev0)
# Requirement already satisfied: typing in c:\users\paul\anaconda3\lib\site-packages (from Resemblyzer) (3.7.4.3)
# Requirement already satisfied: librosa>=0.6.1 in c:\users\paul\anaconda3\lib\site-packages (from Resemblyzer) (0.9.1)
# Requirement already satisfied: webrtcvad>=2.0.10 in c:\users\paul\anaconda3\lib\site-packages (from Resemblyzer) (2.0.10)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\paul\anaconda3\lib\site-packages (from Resemblyzer) (1.7.1)
# Requirement already satisfied: numpy>=1.10.1 in c:\users\paul\anaconda3\lib\site-packages (from Resemblyzer) (1.20.3)
# Requirement already satisfied: torch>=1.0.1 in c:\users\paul\anaconda3\lib\site-packages (from Resemblyzer) (1.11.0)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\paul\anaconda3\lib\site-packages (from librosa>=0.6.1->Resemblyzer) (5.1.0)
# Requirement already satisfied: pooch>=1.0 in c:\users\paul\anaconda3\lib\site-packages (from librosa>=0.6.1->Resemblyzer) (1.6.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\paul\anaconda3\lib\site-packages (from librosa>=0.6.1->Resemblyzer) (1.1.0)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\paul\anaconda3\lib\site-packages (from librosa>=0.6.1->Resemblyzer) (0.10.3.post1)
# Requirement already satisfied: packaging>=20.0 in c:\users\paul\anaconda3\lib\site-packages (from librosa>=0.6.1->Resemblyzer) (21.0)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\paul\anaconda3\lib\site-packages (from librosa>=0.6.1->Resemblyzer) (2.1.9)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\paul\anaconda3\lib\site-packages (from librosa>=0.6.1->Resemblyzer) (0.2.2)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\paul\anaconda3\lib\site-packages (from librosa>=0.6.1->Resemblyzer) (0.24.2)
# Requirement already satisfied: numba>=0.45.1 in c:\users\paul\anaconda3\lib\site-packages (from librosa>=0.6.1->Resemblyzer) (0.54.1)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\paul\anaconda3\lib\site-packages (from numba>=0.45.1->librosa>=0.6.1->Resemblyzer) (0.37.0)
# Requirement already satisfied: setuptools in c:\users\paul\anaconda3\lib\site-packages (from numba>=0.45.1->librosa>=0.6.1->Resemblyzer) (58.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\paul\anaconda3\lib\site-packages (from packaging>=20.0->librosa>=0.6.1->Resemblyzer) (3.0.4)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\paul\anaconda3\lib\site-packages (from pooch>=1.0->librosa>=0.6.1->Resemblyzer) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\paul\anaconda3\lib\site-packages (from pooch>=1.0->librosa>=0.6.1->Resemblyzer) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\paul\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.6.1->Resemblyzer) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\paul\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.6.1->Resemblyzer) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paul\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.6.1->Resemblyzer) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paul\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.6.1->Resemblyzer) (2021.10.8)
# Requirement already satisfied: six>=1.3 in c:\users\paul\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa>=0.6.1->Resemblyzer) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\paul\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa>=0.6.1->Resemblyzer) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\paul\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa>=0.6.1->Resemblyzer) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\paul\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa>=0.6.1->Resemblyzer) (2.20)
# Requirement already satisfied: typing-extensions in c:\users\paul\anaconda3\lib\site-packages (from torch>=1.0.1->Resemblyzer) (3.10.0.2)
# Requirement already satisfied: inaSpeechSegmenter in c:\users\paul\anaconda3\lib\site-packages (0.7.3)
# Requirement already satisfied: pyannote.algorithms in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (0.8)
# Requirement already satisfied: pyannote.parser in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (0.8)
# Requirement already satisfied: pytextgrid in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (0.1.4)
# Requirement already satisfied: numpy in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (1.20.3)
# Requirement already satisfied: pyannote.core in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (4.4)
# Requirement already satisfied: matplotlib in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (3.4.3)
# Requirement already satisfied: soundfile in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (0.10.3.post1)
# Requirement already satisfied: tensorflow in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (2.8.0)
# Requirement already satisfied: scikit-image in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (0.18.3)
# Requirement already satisfied: pandas in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (1.3.4)
# Requirement already satisfied: Pyro4 in c:\users\paul\anaconda3\lib\site-packages (from inaSpeechSegmenter) (4.82)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\paul\anaconda3\lib\site-packages (from matplotlib->inaSpeechSegmenter) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\paul\anaconda3\lib\site-packages (from matplotlib->inaSpeechSegmenter) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\paul\anaconda3\lib\site-packages (from matplotlib->inaSpeechSegmenter) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\paul\anaconda3\lib\site-packages (from matplotlib->inaSpeechSegmenter) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\paul\anaconda3\lib\site-packages (from matplotlib->inaSpeechSegmenter) (3.0.4)
# Requirement already satisfied: six in c:\users\paul\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->inaSpeechSegmenter) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\paul\anaconda3\lib\site-packages (from pandas->inaSpeechSegmenter) (2021.3)
# Requirement already satisfied: docopt>=0.6.2 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.algorithms->inaSpeechSegmenter) (0.6.2)
# Requirement already satisfied: networkx>=2.1 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.algorithms->inaSpeechSegmenter) (2.6.3)
# Requirement already satisfied: joblib>=0.9.4 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.algorithms->inaSpeechSegmenter) (1.1.0)
# Requirement already satisfied: munkres>=1.0.7 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.algorithms->inaSpeechSegmenter) (1.1.4)
# Requirement already satisfied: scikit-learn>=0.17 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.algorithms->inaSpeechSegmenter) (0.24.2)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.algorithms->inaSpeechSegmenter) (1.7.1)
# Requirement already satisfied: sortedcollections>=1.0.1 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.algorithms->inaSpeechSegmenter) (2.1.0)
# Requirement already satisfied: xarray>=0.8.2 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.algorithms->inaSpeechSegmenter) (2022.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.core->inaSpeechSegmenter) (3.10.0.2)
# Requirement already satisfied: sortedcontainers>=2.0.4 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.core->inaSpeechSegmenter) (2.4.0)
# Requirement already satisfied: simplejson>=3.8.1 in c:\users\paul\anaconda3\lib\site-packages (from pyannote.core->inaSpeechSegmenter) (3.17.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\paul\anaconda3\lib\site-packages (from scikit-learn>=0.17->pyannote.algorithms->inaSpeechSegmenter) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\paul\anaconda3\lib\site-packages (from xarray>=0.8.2->pyannote.algorithms->inaSpeechSegmenter) (21.0)
# Requirement already satisfied: serpent>=1.27 in c:\users\paul\anaconda3\lib\site-packages (from Pyro4->inaSpeechSegmenter) (1.40)
# Requirement already satisfied: imageio>=2.3.0 in c:\users\paul\anaconda3\lib\site-packages (from scikit-image->inaSpeechSegmenter) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\paul\anaconda3\lib\site-packages (from scikit-image->inaSpeechSegmenter) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\paul\anaconda3\lib\site-packages (from scikit-image->inaSpeechSegmenter) (1.1.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\paul\anaconda3\lib\site-packages (from soundfile->inaSpeechSegmenter) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\paul\anaconda3\lib\site-packages (from cffi>=1.0->soundfile->inaSpeechSegmenter) (2.20)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (3.2.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (1.44.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (13.0.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (1.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (0.2.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (2.8.0.dev2021122109)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (1.12.1)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (0.5.3)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (2.0)
# Requirement already satisfied: setuptools in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (58.0.4)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (0.24.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (3.20.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\paul\anaconda3\lib\site-packages (from tensorflow->inaSpeechSegmenter) (1.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\paul\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow->inaSpeechSegmenter) (0.37.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\paul\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\paul\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\paul\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (2.0.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\paul\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\paul\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\paul\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (2.6.5)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\paul\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\paul\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\paul\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\paul\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\paul\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\paul\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\paul\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\paul\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\paul\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paul\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paul\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\paul\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\paul\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->inaSpeechSegmenter) (3.2.0)
# Requirement already satisfied: spectralcluster in c:\users\paul\anaconda3\lib\site-packages (0.2.4)
# Requirement already satisfied: pydub in c:\users\paul\anaconda3\lib\site-packages (0.25.1)

# %%
def count_speakers(audio_path):
    
    def different_speakers(audio_path):
        
        def extract_speech(audio_path):
            segmentation = Segmenter(detect_gender=False)
            return segmentation(audio_path)
        def concatenate_segments(segmentation):
            t1 = [] #Temps de début de parole
            t2 = [] #Temps de fin de parole

            #Remplissage des tableaux précédents
            for i in range(len(segmentation)):
                #if (segmentation[i][0] == 'male') or (segmentation[i][0] == 'female'):
                if segmentation[i][0] == 'speech':
                    t1.append(segmentation[i][1])
                    t2.append(segmentation[i][2])

            #Importation du fichier .wav dont on veut les différents locuteurs
            newAudio = AudioSegment.from_wav(audio_path)
            #Génération de deux fichiers audio vides
            audio = AudioSegment.empty()

            # Génération fichier
            for i in range(len(t1)):
                audio += newAudio[t1[i]*1000:t2[i]*1000]
            audio.export(out_f = "cut_audio.wav", 
                                format = "wav")
            return "cut_audio.wav"

        # On segmente l'audio selon les différents locuteurs
        def speaker_segmentation(audio):
            labelling = []
            if os.stat(audio).st_size > 100000 :
                wav_fpath = Path('/content/'+audio)
                wav = preprocess_wav(wav_fpath)
                encoder = VoiceEncoder("cpu")
                _, cont_embeds, wav_splits = encoder.embed_utterance(wav, return_partials=True, rate=16)

                # Pour déterminer les différents locuteurs/locutrices, on clusterise
                refinement_options = RefinementOptions(gaussian_blur_sigma=1,
                                                        p_percentile=0.90,
                                                        thresholding_soft_multiplier=0.01,
                                                        thresholding_type=ThresholdType.RowMax,
                                                        refinement_sequence=ICASSP2018_REFINEMENT_SEQUENCE)

                clusterer = SpectralClusterer(min_clusters=2,
                                              max_clusters=100,
                                              refinement_options=refinement_options)

                labels = clusterer.predict(cont_embeds)

                times = [((s.start + s.stop) / 2) / sampling_rate for s in wav_splits]
                start_time = 0

                for i,time in enumerate(times):
                    if i>0 and labels[i]!=labels[i-1]:
                        temp = [str(labels[i-1]),start_time,time]
                        labelling.append(tuple(temp))
                        start_time = time
                    if i==len(times)-1:
                        temp = [str(labels[i]),start_time,time]
                        labelling.append(tuple(temp))
            else:
                labelling.append(-1)
            return labelling
            
        def extract_audios(labelling):
            audio = AudioSegment.from_wav(audio_path)
            L=[]
            for t in labelling:
                if not(t == -1):
                    new_audio = AudioSegment.empty()
                    new_audio = audio[t[1]*1000:t[2]*1000]
                    out_f= "new_audio"+str([t[1],t[2]])+".wav"
                    new_audio.export(out_f , format = "wav")
                    L.append(out_f)
            return(L)
        ## Exécution partie 1 : 
        # Etape I : 
        segmentation = extract_speech(audio_path)
        # Etape II : 
        newAudio = concatenate_segments(segmentation)
        # Etape III :
        labelling = speaker_segmentation(newAudio)
        # Etape IV : 
        resultat = extract_audios(labelling)
        
                
        return (resultat, labelling)

    def get_char_son(fichier):
        signal, sr=librosa.load(fichier)
        S = np.abs(librosa.stft(signal))
        comps, acts = librosa.decompose.decompose(S, n_components=1)
        data=pd.DataFrame([np.ravel(comps).tolist()])
        data['ID']=fichier
        return(data.set_index('ID'))
    
    def predict_sound(tab):
        loaded_model = joblib.load('Reconnaissance Femme_Homme/my_model.pkl"')
        if loaded_model.predict(data)[0]==0:
            return('Homme')
        return('Femme')
    
    files, labelling = speaker_segmentation(audio_path)
    dict_speaker = {}
    dict_speaker_sex = {}
    for i in range(len(files)):
        tab = get_char_son(files[i])
        pred_sex = predict_sound(tab)
        dict_speaker[labelling[i]] = 1 + dict_speaker[labelling[i]]
        dict_speaker_sex[labelling[i]] = pred_sex

    c_male = 0
    c_female = 0 
    for cle,valeur in dict_speaker_sex.items():
        if valeur == 'Homme':
            c_male = c_male + dict_speaker[cle]
        elif valeur == 'Femme':
            c_female = c_female + dict_speaker[cle]

    result = {'M':c_male , 'F':c_female}
    return result

# %%
count_speakers("moviesoundclips.net_test/moviesoundclips.net/15.wav")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5616/541593695.py in <module>
# ----> 1 count_speakers("moviesoundclips.net_test/moviesoundclips.net/15.wav")
#
# ~\AppData\Local\Temp/ipykernel_5616/3054309882.py in count_speakers(audio_path)
#     103         return('Femme')
#     104
# --> 105     files, labelling = speaker_segmentation(audio_path)
#     106     dict_speaker = {}
#     107     dict_speaker_sex = {}
#
# NameError: name 'speaker_segmentation' is not defined

# %%
def count_speakers1(audio_path):
    
    def extract_speech(audio_path):
        segmentation = Segmenter(detect_gender=False)
        return segmentation(audio_path)
    
    def concatenate_segments(segmentation):
        t1 = [] #Temps de début de parole
        t2 = [] #Temps de fin de parole

        #Remplissage des tableaux précédents
        for i in range(len(segmentation)):
            #if (segmentation[i][0] == 'male') or (segmentation[i][0] == 'female'):
            if segmentation[i][0] == 'speech':
                t1.append(segmentation[i][1])
                t2.append(segmentation[i][2])

        #Importation du fichier .wav dont on veut les différents locuteurs
        newAudio = AudioSegment.from_wav(audio_path)
        #Génération de deux fichiers audio vides
        audio = AudioSegment.empty()

        # Génération fichier
        for i in range(len(t1)):
            audio += newAudio[t1[i]*1000:t2[i]*1000]
        audio.export(out_f = "cut_audio.wav", 
                            format = "wav")
        return "cut_audio.wav"
    
    def speaker_segmentation(audio):
        labelling = []
        if os.stat(audio).st_size > 100000 :
            wav_fpath = Path(audio)
            wav = preprocess_wav(wav_fpath)
            encoder = VoiceEncoder("cpu")
            _, cont_embeds, wav_splits = encoder.embed_utterance(wav, return_partials=True, rate=16)

            # Pour déterminer les différents locuteurs/locutrices, on clusterise
            refinement_options = RefinementOptions(gaussian_blur_sigma=1,
                                                    p_percentile=0.90,
                                                    thresholding_soft_multiplier=0.01,
                                                    thresholding_type=ThresholdType.RowMax,
                                                    refinement_sequence=ICASSP2018_REFINEMENT_SEQUENCE)

            clusterer = SpectralClusterer(min_clusters=2,
                                          max_clusters=100,
                                          refinement_options=refinement_options)

            labels = clusterer.predict(cont_embeds)

            times = [((s.start + s.stop) / 2) / sampling_rate for s in wav_splits]
            start_time = 0

            for i,time in enumerate(times):
                if i>0 and labels[i]!=labels[i-1]:
                    temp = [str(labels[i-1]),start_time,time]
                    labelling.append(tuple(temp))
                    start_time = time
                if i==len(times)-1:
                    temp = [str(labels[i]),start_time,time]
                    labelling.append(tuple(temp))
        else:
            labelling.append(-1)
        return labelling
    
    def extract_audios(labelling):
        audio = AudioSegment.from_wav(audio_path)
        L=[]
        for t in labelling:
            if not(t == -1):
                new_audio = AudioSegment.empty()
                new_audio = audio[t[1]*1000:t[2]*1000]
                out_f= "new_audio"+str([t[1],t[2]])+".wav"
                new_audio.export(out_f , format = "wav")
                L.append(out_f)
        return(L)
    
    def different_speakers(audio_path):
    
        ## Exécution partie 1 : 
        # Etape I : 
        segmentation = extract_speech(audio_path)
        # Etape II : 
        newAudio = concatenate_segments(segmentation)
        # Etape III :
        labelling = speaker_segmentation(newAudio)
        # Etape IV : 
        resultat = extract_audios(labelling)
            
        return [resultat, labelling]

    def get_char_son(fichier):
        signal, sr=librosa.load(fichier)
        S = np.abs(librosa.stft(signal))
        comps, acts = librosa.decompose.decompose(S, n_components=1)
        data=pd.DataFrame([np.ravel(comps).tolist()])
        data['ID']=fichier
        return(data.set_index('ID'))
    
    def predict_sound(tab):
        loaded_model = joblib.load('Reconnaissance Femme_Homme\my_model.pkl')
        if loaded_model.predict(tab)[0]==0:
            return('Homme')
        return('Femme')
    
    part1 = different_speakers(audio_path)
    print(part1)
    files = part1[0]
    labelling = part1[1]
    dict_speaker = {}
    dict_speaker_sex = {}
    for i in range(len(files)):
        tab = get_char_son(files[i])
        pred_sex = predict_sound(tab)
        try:
            dict_speaker[labelling[i]] = 1 + dict_speaker[labelling[i]]
        except:
            dict_speaker[labelling[i]] = 1
        dict_speaker_sex[labelling[i]] = pred_sex

    c_male = 0
    c_female = 0 
    for cle,valeur in dict_speaker_sex.items():
        if valeur == 'Homme':
            c_male = c_male + dict_speaker[cle]
        elif valeur == 'Femme':
            c_female = c_female + dict_speaker[cle]

    result = {'M':c_male , 'F':c_female}
    return result

# %%
count_speakers1("moviesoundclips.net_test/moviesoundclips.net/959.wav")
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=24000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.01 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.0].wav', 'new_audio[2.0, 2.66].wav', 'new_audio[2.66, 4.1].wav', 'new_audio[4.1, 5.42].wav', 'new_audio[5.42, 6.5].wav', 'new_audio[6.5, 7.76].wav', 'new_audio[7.76, 8.78].wav', 'new_audio[8.78, 9.8].wav'], [('4', 0, 2.0), ('6', 2.0, 2.66), ('3', 2.66, 4.1), ('2', 4.1, 5.42), ('7', 5.42, 6.5), ('1', 6.5, 7.76), ('0', 7.76, 8.78), ('5', 8.78, 9.8)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# {'M': 8, 'F': 0}

# %%
import os
res={}
L=os.listdir('moviesoundclips.net_test/moviesoundclips.net/')
for i in range(len(L)):
    sep=(L[i].find('.'))
    num=L[i][:sep]
    res_prov=count_speakers1("moviesoundclips.net_test/moviesoundclips.net/"+L[i])
    res[str(num)]=res_prov
    print(i/len(L))
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=11025, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0.02292936 0.02088435 0.01217182 ... 0.         0.         0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.46].wav', 'new_audio[1.46, 2.84].wav', 'new_audio[2.84, 3.2].wav', 'new_audio[3.2, 4.34].wav', 'new_audio[4.34, 6.08].wav', 'new_audio[6.08, 6.62].wav', 'new_audio[6.62, 7.94].wav', 'new_audio[7.94, 8.84].wav', 'new_audio[8.84, 10.64].wav'], [('4', 0, 1.46), ('6', 1.46, 2.84), ('7', 2.84, 3.2), ('0', 3.2, 4.34), ('1', 4.34, 6.08), ('7', 6.08, 6.62), ('2', 6.62, 7.94), ('5', 7.94, 8.84), ('3', 8.84, 10.64)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.0
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=24000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[-0.03557598 -0.04564996 -0.04120962 ...  0.          0.
#   0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 5.42].wav', 'new_audio[5.42, 6.2].wav', 'new_audio[6.2, 9.32].wav', 'new_audio[9.32, 15.74].wav'], [('1', 0, 5.42), ('0', 5.42, 6.2), ('1', 6.2, 9.32), ('0', 9.32, 15.74)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.004032258064516129
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=24000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[-0.04261611 -0.04472563 -0.04771423 ...  0.          0.
#   0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.94].wav', 'new_audio[1.94, 3.26].wav', 'new_audio[3.26, 4.58].wav', 'new_audio[4.58, 5.96].wav', 'new_audio[5.96, 7.76].wav', 'new_audio[7.76, 7.82].wav', 'new_audio[7.82, 9.5].wav'], [('1', 0, 1.94), ('5', 1.94, 3.26), ('0', 3.26, 4.58), ('4', 4.58, 5.96), ('3', 5.96, 7.76), ('0', 7.76, 7.82), ('2', 7.82, 9.5)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.008064516129032258
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# [[], [-1]]
# 0.012096774193548387
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=24000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.24].wav', 'new_audio[2.24, 3.14].wav', 'new_audio[3.14, 4.34].wav', 'new_audio[4.34, 5.48].wav', 'new_audio[5.48, 7.34].wav', 'new_audio[7.34, 8.3].wav'], [('3', 0, 2.24), ('5', 2.24, 3.14), ('0', 3.14, 4.34), ('4', 4.34, 5.48), ('1', 5.48, 7.34), ('2', 7.34, 8.3)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.016129032258064516
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=24000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.0].wav', 'new_audio[2.0, 3.44].wav'], [('1', 0, 2.0), ('0', 2.0, 3.44)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.020161290322580645
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# [[], [-1]]
# 0.024193548387096774
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# [[], [-1]]
# 0.028225806451612902
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# [[], [-1]]
# 0.03225806451612903
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=48000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.12].wav', 'new_audio[2.12, 2.72].wav', 'new_audio[2.72, 3.14].wav', 'new_audio[3.14, 4.52].wav'], [('2', 0, 2.12), ('0', 2.12, 2.72), ('3', 2.72, 3.14), ('1', 3.14, 4.52)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.036290322580645164
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=48000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.01 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.0].wav', 'new_audio[2.0, 3.38].wav', 'new_audio[3.38, 5.0].wav', 'new_audio[5.0, 6.62].wav'], [('3', 0, 2.0), ('1', 2.0, 3.38), ('2', 3.38, 5.0), ('0', 5.0, 6.62)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.04032258064516129
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=48000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.12].wav', 'new_audio[2.12, 2.9].wav', 'new_audio[2.9, 4.04].wav'], [('0', 0, 2.12), ('2', 2.12, 2.9), ('1', 2.9, 4.04)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.04435483870967742
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# [[], [-1]]
# 0.04838709677419355
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# [[], [-1]]
# 0.05241935483870968
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=24000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.01 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.46].wav', 'new_audio[1.46, 2.96].wav', 'new_audio[2.96, 3.56].wav', 'new_audio[3.56, 4.52].wav', 'new_audio[4.52, 6.02].wav', 'new_audio[6.02, 7.1].wav', 'new_audio[7.1, 7.76].wav', 'new_audio[7.76, 9.5].wav', 'new_audio[9.5, 10.22].wav', 'new_audio[10.22, 11.9].wav'], [('6', 0, 1.46), ('5', 1.46, 2.96), ('0', 2.96, 3.56), ('8', 3.56, 4.52), ('2', 4.52, 6.02), ('7', 6.02, 7.1), ('1', 7.1, 7.76), ('3', 7.76, 9.5), ('1', 9.5, 10.22), ('4', 10.22, 11.9)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.056451612903225805
# ...
#   return np.vstack(
# [[], [-1]]
# 0.4314516129032258
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[-0.01302965 -0.0129094  -0.01563643 ...  0.          0.
#   0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.06].wav', 'new_audio[2.06, 2.96].wav', 'new_audio[2.96, 3.5].wav', 'new_audio[3.5, 3.86].wav'], [('3', 0, 2.06), ('1', 2.06, 2.96), ('2', 2.96, 3.5), ('0', 3.5, 3.86)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.43548387096774194
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# [[], [-1]]
# 0.43951612903225806
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# [[], [-1]]
# 0.4435483870967742
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0.00740407 0.00552459 0.00134508 ... 0.         0.         0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.1].wav', 'new_audio[1.1, 1.28].wav'], [('1', 0, 1.1), ('0', 1.1, 1.28)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.4475806451612903
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.01 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0.00627827 0.00250627 0.00102361 ... 0.         0.         0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.76].wav', 'new_audio[1.76, 2.78].wav', 'new_audio[2.78, 4.4].wav', 'new_audio[4.4, 5.18].wav'], [('2', 0, 1.76), ('3', 1.76, 2.78), ('1', 2.78, 4.4), ('0', 4.4, 5.18)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.45161290322580644
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0.00154604 0.00163207 0.00777019 ... 0.         0.         0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# C:\Users\Paul\anaconda3\lib\site-packages\spectralcluster\refinement.py:260: RuntimeWarning: invalid value encountered in true_divide
#   refined_affinity /= np.expand_dims(row_max, axis=1)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5616/467698996.py in <module>
#       5     sep=(L[i].find('.'))
#       6     num=L[i][:sep]
# ----> 7     res_prov=count_speakers1("moviesoundclips.net_test/moviesoundclips.net/"+L[i])
#       8     res[str(num)]=res_prov
#       9     print(i/len(L))
#
# ~\AppData\Local\Temp/ipykernel_5616/1977004158.py in count_speakers1(audio_path)
#     104         return('Femme')
#     105
# --> 106     part1 = different_speakers(audio_path)
#     107     print(part1)
#     108     files = part1[0]
#
# ~\AppData\Local\Temp/ipykernel_5616/1977004158.py in different_speakers(audio_path)
#      84         newAudio = concatenate_segments(segmentation)
#      85         # Etape III :
# ---> 86         labelling = speaker_segmentation(newAudio)
#      87         # Etape IV :
#      88         resultat = extract_audios(labelling)
#
# ~\AppData\Local\Temp/ipykernel_5616/1977004158.py in speaker_segmentation(audio)
#      47                                           refinement_options=refinement_options)
#      48
# ---> 49             labels = clusterer.predict(cont_embeds)
#      50
#      51             times = [((s.start + s.stop) / 2) / sampling_rate for s in wav_splits]
#
# ~\anaconda3\lib\site-packages\spectralcluster\spectral_clusterer.py in predict(self, embeddings, constraint_matrix)
#     182     else:
#     183       # Do not use Auto-tune.
# --> 184       eigenvectors, n_clusters, _ = self._compute_eigenvectors_ncluster(
#     185           affinity, constraint_matrix)
#     186
#
# ~\anaconda3\lib\site-packages\spectralcluster\spectral_clusterer.py in _compute_eigenvectors_ncluster(self, affinity, constraint_matrix)
#     109     if not self.laplacian_type or self.laplacian_type == LaplacianType.Affinity:
#     110       # Perform eigen decomposion.
# --> 111       (eigenvalues, eigenvectors) = utils.compute_sorted_eigenvectors(affinity)
#     112       # Get number of clusters.
#     113       n_clusters, max_delta_norm = utils.compute_number_of_clusters(
#
# ~\anaconda3\lib\site-packages\spectralcluster\utils.py in compute_sorted_eigenvectors(input_matrix, descend)
#      54   """
#      55   # Eigen decomposition.
# ---> 56   eigenvalues, eigenvectors = np.linalg.eig(input_matrix)
#      57   eigenvalues = eigenvalues.real
#      58   eigenvectors = eigenvectors.real
#
# <__array_function__ internals> in eig(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in eig(a)
#    1315     _assert_stacked_2d(a)
#    1316     _assert_stacked_square(a)
# -> 1317     _assert_finite(a)
#    1318     t, result_t = _commonType(a)
#    1319
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in _assert_finite(*arrays)
#     206     for a in arrays:
#     207         if not isfinite(a).all():
# --> 208             raise LinAlgError("Array must not contain infs or NaNs")
#     209
#     210 def _is_empty_2d(arr):
#
# LinAlgError: Array must not contain infs or NaNs

# %%
res
# Out:
# {'100': {'M': 2, 'F': 7},
#  '1065': {'M': 1, 'F': 3},
#  '1156': {'M': 0, 'F': 7},
#  '1162': {'M': 0, 'F': 0},
#  '1167': {'M': 5, 'F': 1},
#  '1226': {'M': 0, 'F': 2},
#  '125': {'M': 0, 'F': 0},
#  '126': {'M': 0, 'F': 0},
#  '127': {'M': 0, 'F': 0},
#  '1310': {'M': 2, 'F': 2},
#  '1313': {'M': 1, 'F': 3},
#  '1327': {'M': 0, 'F': 3},
#  '137': {'M': 0, 'F': 0},
#  '15': {'M': 0, 'F': 0},
#  '1508': {'M': 7, 'F': 3},
#  '1532': {'M': 4, 'F': 3},
#  '1551': {'M': 7, 'F': 3},
#  '156': {'M': 5, 'F': 3},
#  '157': {'M': 8, 'F': 1},
#  '161': {'M': 0, 'F': 0},
#  '1666': {'M': 7, 'F': 3},
#  '1727': {'M': 2, 'F': 1},
#  '173': {'M': 1, 'F': 4},
#  '1730': {'M': 4, 'F': 0},
#  '1731': {'M': 2, 'F': 0},
#  '1754': {'M': 0, 'F': 0},
#  '1757': {'M': 3, 'F': 5},
#  '1758': {'M': 12, 'F': 9},
#  '1770': {'M': 2, 'F': 0},
#  '1777': {'M': 6, 'F': 0},
#  '1819': {'M': 6, 'F': 2},
#  '1826': {'M': 2, 'F': 0},
#  '1827': {'M': 2, 'F': 0},
#  '1832': {'M': 4, 'F': 1},
#  '1875': {'M': 5, 'F': 6},
#  '1892': {'M': 1, 'F': 1},
#  '1976': {'M': 4, 'F': 5},
#  '1990': {'M': 3, 'F': 4},
#  '1994': {'M': 20, 'F': 3},
#  '1996': {'M': 2, 'F': 3},
#  '2062': {'M': 1, 'F': 1},
#  '2071': {'M': 16, 'F': 0},
#  '2087': {'M': 2, 'F': 0},
#  '2097': {'M': 0, 'F': 0},
#  '2129': {'M': 2, 'F': 0},
#  '2134': {'M': 7, 'F': 3},
#  '2159': {'M': 0, 'F': 0},
#  '2163': {'M': 10, 'F': 0},
#  '2164': {'M': 1, 'F': 1},
#  '2191': {'M': 0, 'F': 0},
#  '2195': {'M': 0, 'F': 0},
#  '220': {'M': 0, 'F': 0},
#  '2213': {'M': 9, 'F': 1},
#  '2296': {'M': 3, 'F': 4},
#  '2317': {'M': 1, 'F': 1},
#  '2322': {'M': 0, 'F': 0},
#  '2375': {'M': 0, 'F': 2},
#  '2382': {'M': 6, 'F': 3},
#  '2389': {'M': 2, 'F': 7},
#  '2392': {'M': 0, 'F': 2},
#  '2395': {'M': 1, 'F': 5},
#  '240': {'M': 0, 'F': 0},
#  '2406': {'M': 3, 'F': 1},
#  '2428': {'M': 2, 'F': 5},
#  '2430': {'M': 0, 'F': 6},
#  '2453': {'M': 0, 'F': 3},
#  '2455': {'M': 0, 'F': 2},
#  '2458': {'M': 1, 'F': 4},
#  '2463': {'M': 0, 'F': 0},
#  '2470': {'M': 0, 'F': 11},
#  '2481': {'M': 1, 'F': 9},
#  '2538': {'M': 3, 'F': 0},
#  '2542': {'M': 0, 'F': 0},
#  '2546': {'M': 1, 'F': 2},
#  '2553': {'M': 8, 'F': 1},
#  '2569': {'M': 5, 'F': 0},
#  '2636': {'M': 2, 'F': 0},
#  '2667': {'M': 2, 'F': 2},
#  '2693': {'M': 0, 'F': 0},
#  '2696': {'M': 1, 'F': 1},
#  '2704': {'M': 0, 'F': 0},
#  '2724': {'M': 0, 'F': 3},
#  '2751': {'M': 0, 'F': 0},
#  '2753': {'M': 0, 'F': 3},
#  '2800': {'M': 1, 'F': 1},
#  '2801': {'M': 3, 'F': 0},
#  '2814': {'M': 0, 'F': 2},
#  '2832': {'M': 0, 'F': 0},
#  '2888': {'M': 0, 'F': 3},
#  '2905': {'M': 0, 'F': 3},
#  '2935': {'M': 0, 'F': 2},
#  '2957': {'M': 3, 'F': 5},
#  '2963': {'M': 2, 'F': 0},
#  '298': {'M': 0, 'F': 0},
#  '2982': {'M': 0, 'F': 2},
#  '300': {'M': 0, 'F': 3},
#  '3001': {'M': 0, 'F': 3},
#  '3011': {'M': 0, 'F': 0},
#  '3018': {'M': 5, 'F': 4},
#  '3019': {'M': 7, 'F': 2},
#  '3022': {'M': 0, 'F': 2},
#  '3037': {'M': 0, 'F': 2},
#  '3039': {'M': 0, 'F': 13},
#  '305': {'M': 0, 'F': 0},
#  '3067': {'M': 0, 'F': 7},
#  '3070': {'M': 0, 'F': 2},
#  '3113': {'M': 1, 'F': 2},
#  '313': {'M': 0, 'F': 0},
#  '3148': {'M': 2, 'F': 2},
#  '3158': {'M': 0, 'F': 0},
#  '32': {'M': 0, 'F': 0},
#  '3235': {'M': 0, 'F': 2},
#  '3248': {'M': 0, 'F': 4}}

# %%
len(L)
# Out:
# 248

# %%
L.index('3248.wav')
# Out:
# 112

# %%
res={}
L=os.listdir('moviesoundclips.net_test/moviesoundclips.net/')
for i in range(len(L)):
    sep=(L[i].find('.'))
    num=L[i][:sep]
    res_prov=count_speakers1("moviesoundclips.net_test/moviesoundclips.net/"+L[i])
    res[str(num)]=res_prov
    print(i/len(L))

# %%
tab=pd.DataFrame(res).to_csv('Equipe 2 - Résultats.csv',';')

# %%
tab

# %%
pd.DataFrame(res).trans
# Out:
#    100  1065  1156  1162  1167  1226  125  126  127  1310  ...  305  3067  \
# M    2     1     0     0     5     0    0    0    0     2  ...    0     0
# F    7     3     7     0     1     2    0    0    0     2  ...    0     7
#
#    3070  3113  313  3148  3158  32  3235  3248
# M     0     1    0     2     0   0     0     0
# F     2     2    0     2     0   0     2     4
#
# [2 rows x 113 columns]

# %%
print(L)
# Out:
# ['100.wav', '1065.wav', '1156.wav', '1162.wav', '1167.wav', '1226.wav', '125.wav', '126.wav', '127.wav', '1310.wav', '1313.wav', '1327.wav', '137.wav', '15.wav', '1508.wav', '1532.wav', '1551.wav', '156.wav', '157.wav', '161.wav', '1666.wav', '1727.wav', '173.wav', '1730.wav', '1731.wav', '1754.wav', '1757.wav', '1758.wav', '1770.wav', '1777.wav', '1819.wav', '1826.wav', '1827.wav', '1832.wav', '1875.wav', '1892.wav', '1976.wav', '1990.wav', '1994.wav', '1996.wav', '2062.wav', '2071.wav', '2087.wav', '2097.wav', '2129.wav', '2134.wav', '2159.wav', '2163.wav', '2164.wav', '2191.wav', '2195.wav', '220.wav', '2213.wav', '2296.wav', '2317.wav', '2322.wav', '2375.wav', '2382.wav', '2389.wav', '2392.wav', '2395.wav', '240.wav', '2406.wav', '2428.wav', '2430.wav', '2453.wav', '2455.wav', '2458.wav', '2463.wav', '2470.wav', '2481.wav', '2538.wav', '2542.wav', '2546.wav', '2553.wav', '2569.wav', '2636.wav', '2667.wav', '2693.wav', '2696.wav', '2704.wav', '2724.wav', '2751.wav', '2753.wav', '2800.wav', '2801.wav', '2814.wav', '2832.wav', '2888.wav', '2905.wav', '2935.wav', '2957.wav', '2963.wav', '298.wav', '2982.wav', '300.wav', '3001.wav', '3011.wav', '3018.wav', '3019.wav', '3022.wav', '3037.wav', '3039.wav', '305.wav', '3067.wav', '3070.wav', '3113.wav', '313.wav', '3148.wav', '3158.wav', '32.wav', '3235.wav', '3248.wav', '3250.wav', '3286.wav', '3293.wav', '3298.wav', '3302.wav', '3306.wav', '3316.wav', '3344.wav', '3362.wav', '3377.wav', '3382.wav', '339.wav', '3409.wav', '3417.wav', '3423.wav', '3454.wav', '3480.wav', '3484.wav', '3487.wav', '3492.wav', '3494.wav', '3500.wav', '3508.wav', '3513.wav', '3520.wav', '3530.wav', '3534.wav', '3549.wav', '3580.wav', '360.wav', '3604.wav', '3609.wav', '3610.wav', '3630.wav', '3631.wav', '3647.wav', '3651.wav', '3655.wav', '366.wav', '3663.wav', '3667.wav', '3716.wav', '3721.wav', '3762.wav', '3794.wav', '38.wav', '383.wav', '3882.wav', '3899.wav', '3911.wav', '3917.wav', '3924.wav', '3976.wav', '398.wav', '3991.wav', '3992.wav', '401.wav', '403.wav', '4046.wav', '407.wav', '4086.wav', '4090.wav', '4102.wav', '4104.wav', '4182.wav', '4187.wav', '4190.wav', '4222.wav', '4243.wav', '4244.wav', '4249.wav', '4252.wav', '4259.wav', '4266.wav', '4283.wav', '4295.wav', '4301.wav', '4305.wav', '4310.wav', '4312.wav', '4357.wav', '4422.wav', '4423.wav', '4429.wav', '4438.wav', '4445.wav', '45.wav', '451.wav', '463.wav', '47.wav', '472.wav', '480.wav', '53.wav', '553.wav', '563.wav', '564.wav', '574.wav', '586.wav', '587.wav', '594.wav', '599.wav', '612.wav', '622.wav', '673.wav', '677.wav', '681.wav', '702.wav', '703.wav', '713.wav', '724.wav', '732.wav', '740.wav', '752.wav', '756.wav', '76.wav', '762.wav', '765.wav', '777.wav', '803.wav', '812.wav', '849.wav', '85.wav', '863.wav', '873.wav', '875.wav', '900.wav', '905.wav', '906.wav', '915.wav', '918.wav', '942.wav', '956.wav', '957.wav', '959.wav', '973.wav']

# %%
import os
res2={}
L=os.listdir('moviesoundclips.net_test/moviesoundclips.net/')
for i in range(114,len(L)):
    sep=(L[i].find('.'))
    num=L[i][:sep]
    res_prov=count_speakers1("moviesoundclips.net_test/moviesoundclips.net/"+L[i])
    res2[str(num)]=res_prov
    print(i/len(L))
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0.05298372 0.10000366 0.06846321 ... 0.         0.         0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.04].wav', 'new_audio[1.04, 1.28].wav'], [('1', 0, 1.04), ('0', 1.04, 1.28)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.4596774193548387
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0.02312987 0.04368008 0.03904844 ... 0.         0.         0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.58].wav', 'new_audio[1.58, 1.94].wav'], [('0', 0, 1.58), ('1', 1.58, 1.94)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.4637096774193548
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# [[], [-1]]
# 0.46774193548387094
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[-0.05465722 -0.08844473 -0.0744979  ...  0.          0.
#   0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.88].wav', 'new_audio[1.88, 2.84].wav', 'new_audio[2.84, 3.8].wav', 'new_audio[3.8, 3.98].wav', 'new_audio[3.98, 5.36].wav', 'new_audio[5.36, 6.38].wav'], [('4', 0, 1.88), ('3', 1.88, 2.84), ('2', 2.84, 3.8), ('3', 3.8, 3.98), ('1', 3.98, 5.36), ('0', 5.36, 6.38)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.4717741935483871
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.03 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[-0.00414849 -0.00960962 -0.01471499 ...  0.          0.
#   0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.82].wav', 'new_audio[1.82, 3.2].wav', 'new_audio[3.2, 4.58].wav', 'new_audio[4.58, 5.78].wav', 'new_audio[5.78, 7.1].wav', 'new_audio[7.1, 8.6].wav', 'new_audio[8.6, 9.98].wav', 'new_audio[9.98, 11.12].wav', 'new_audio[11.12, 12.38].wav', 'new_audio[12.38, 13.82].wav', 'new_audio[13.82, 15.26].wav', 'new_audio[15.26, 16.7].wav', 'new_audio[16.7, 18.32].wav', 'new_audio[18.32, 19.28].wav', 'new_audio[19.28, 19.4].wav', 'new_audio[19.4, 20.66].wav'], [('7', 0, 1.82), ('9', 1.82, 3.2), ('3', 3.2, 4.58), ('14', 4.58, 5.78), ('6', 5.78, 7.1), ('11', 7.1, 8.6), ('0', 8.6, 9.98), ('4', 9.98, 11.12), ('1', 11.12, 12.38), ('13', 12.38, 13.82), ('12', 13.82, 15.26), ('2', 15.26, 16.7), ('5', 16.7, 18.32), ('8', 18.32, 19.28), ('4', 19.28, 19.4), ('10', 19.4, 20.66)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.47580645161290325
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[-0.02163631 -0.03605672 -0.03387089 ...  0.          0.
#   0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 6.02].wav', 'new_audio[6.02, 6.98].wav', 'new_audio[6.98, 8.78].wav', 'new_audio[8.78, 8.84].wav', 'new_audio[8.84, 9.02].wav', 'new_audio[9.02, 10.88].wav', 'new_audio[10.88, 12.44].wav', 'new_audio[12.44, 14.3].wav', 'new_audio[14.3, 16.76].wav', 'new_audio[16.76, 17.84].wav', 'new_audio[17.84, 19.82].wav', 'new_audio[19.82, 19.82].wav'], [('0', 0, 6.02), ('1', 6.02, 6.98), ('4', 6.98, 8.78), ('1', 8.78, 8.84), ('4', 8.84, 9.02), ('1', 9.02, 10.88), ('6', 10.88, 12.44), ('2', 12.44, 14.3), ('3', 14.3, 16.76), ('1', 16.76, 17.84), ('5', 17.84, 19.82), ('2', 19.82, 19.82)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5616/1299341938.py in <module>
#       5     sep=(L[i].find('.'))
#       6     num=L[i][:sep]
# ----> 7     res_prov=count_speakers1("moviesoundclips.net_test/moviesoundclips.net/"+L[i])
#       8     res2[str(num)]=res_prov
#       9     print(i/len(L))
#
# ~\AppData\Local\Temp/ipykernel_5616/1977004158.py in count_speakers1(audio_path)
#     111     dict_speaker_sex = {}
#     112     for i in range(len(files)):
# --> 113         tab = get_char_son(files[i])
#     114         pred_sex = predict_sound(tab)
#     115         try:
#
# ~\AppData\Local\Temp/ipykernel_5616/1977004158.py in get_char_son(fichier)
#      91
#      92     def get_char_son(fichier):
# ---> 93         signal, sr=librosa.load(fichier)
#      94         S = np.abs(librosa.stft(signal))
#      95         comps, acts = librosa.decompose.decompose(S, n_components=1)
#
# ~\anaconda3\lib\site-packages\librosa\util\decorators.py in inner_f(*args, **kwargs)
#      86             extra_args = len(args) - len(all_args)
#      87             if extra_args <= 0:
# ---> 88                 return f(*args, **kwargs)
#      89
#      90             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     181
#     182     if sr is not None:
# --> 183         y = resample(y, orig_sr=sr_native, target_sr=sr, res_type=res_type)
#     184
#     185     else:
#
# ~\anaconda3\lib\site-packages\librosa\util\decorators.py in inner_f(*args, **kwargs)
#      86             extra_args = len(args) - len(all_args)
#      87             if extra_args <= 0:
# ---> 88                 return f(*args, **kwargs)
#      89
#      90             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     615         y_hat = soxr.resample(y.T, orig_sr, target_sr, quality=res_type).T
#     616     else:
# --> 617         y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     618
#     619     if fix:
#
# ~\anaconda3\lib\site-packages\resampy\core.py in resample(x, sr_orig, sr_new, axis, filter, **kwargs)
#      95
#      96     if shape[axis] < 1:
# ---> 97         raise ValueError('Input signal length={} is too small to '
#      98                          'resample from {}->{}'.format(x.shape[axis], sr_orig, sr_new))
#      99
#
# ValueError: Input signal length=0 is too small to resample from 44100->22050

# %%
res2
# Out:
# {'3286': {'M': 2, 'F': 0},
#  '3293': {'M': 2, 'F': 0},
#  '3298': {'M': 0, 'F': 0},
#  '3302': {'M': 5, 'F': 1},
#  '3306': {'M': 12, 'F': 4}}

# %%
Def_1={**res, **res2}

# %%
L.index('3306.wav')
# Out:
# 118

# %%
import os
res3={}
L=os.listdir('moviesoundclips.net_test/moviesoundclips.net/')
for i in range(120,len(L)):
    sep=(L[i].find('.'))
    num=L[i][:sep]
    try:
        res_prov=count_speakers1("moviesoundclips.net_test/moviesoundclips.net/"+L[i])
        res3[str(num)]=res_prov
    except:
        print('Erreur')
    print(i/len(L))
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.01 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[-0.01818463 -0.02996667 -0.02566169 ...  0.          0.
#   0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.24].wav', 'new_audio[2.24, 3.92].wav', 'new_audio[3.92, 4.94].wav', 'new_audio[4.94, 5.54].wav', 'new_audio[5.54, 6.86].wav'], [('0', 0, 2.24), ('1', 2.24, 3.92), ('3', 3.92, 4.94), ('2', 4.94, 5.54), ('4', 5.54, 6.86)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.4838709677419355
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.01 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0.01798352 0.02735349 0.02174394 ... 0.         0.         0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.22].wav', 'new_audio[1.22, 1.82].wav', 'new_audio[1.82, 3.08].wav', 'new_audio[3.08, 3.62].wav', 'new_audio[3.62, 4.7].wav', 'new_audio[4.7, 6.38].wav', 'new_audio[6.38, 7.22].wav', 'new_audio[7.22, 8.96].wav', 'new_audio[8.96, 9.56].wav', 'new_audio[9.56, 10.82].wav', 'new_audio[10.82, 11.24].wav', 'new_audio[11.24, 12.68].wav', 'new_audio[12.68, 12.74].wav', 'new_audio[12.74, 13.16].wav', 'new_audio[13.16, 13.7].wav', 'new_audio[13.7, 15.08].wav', 'new_audio[15.08, 15.26].wav', 'new_audio[15.26, 15.44].wav', 'new_audio[15.44, 15.68].wav', 'new_audio[15.68, 16.28].wav', 'new_audio[16.28, 16.34].wav', 'new_audio[16.34, 16.4].wav', 'new_audio[16.4, 16.94].wav', 'new_audio[16.94, 18.32].wav', 'new_audio[18.32, 18.98].wav', 'new_audio[18.98, 20.18].wav', 'new_audio[20.18, 21.08].wav', 'new_audio[21.08, 21.8].wav'], [('19', 0, 1.22), ('7', 1.22, 1.82), ('8', 1.82, 3.08), ('18', 3.08, 3.62), ('11', 3.62, 4.7), ('13', 4.7, 6.38), ('6', 6.38, 7.22), ('5', 7.22, 8.96), ('16', 8.96, 9.56), ('4', 9.56, 10.82), ('2', 10.82, 11.24), ('1', 11.24, 12.68), ('2', 12.68, 12.74), ('4', 12.74, 13.16), ('2', 13.16, 13.7), ('14', 13.7, 15.08), ('2', 15.08, 15.26), ('17', 15.26, 15.44), ('2', 15.44, 15.68), ('10', 15.68, 16.28), ('2', 16.28, 16.34), ('10', 16.34, 16.4), ('12', 16.4, 16.94), ('3', 16.94, 18.32), ('15', 18.32, 18.98), ('9', 18.98, 20.18), ('0', 20.18, 21.08), ('7', 21.08, 21.8)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.4879032258064516
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[-0.00100393 -0.00021352  0.000172   ...  0.          0.
#   0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.16].wav', 'new_audio[1.16, 1.58].wav'], [('1', 0, 1.16), ('0', 1.16, 1.58)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.49193548387096775
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0.00942853 0.01429803 0.01259339 ... 0.         0.         0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.04].wav', 'new_audio[1.04, 1.22].wav'], [('1', 0, 1.04), ('0', 1.04, 1.22)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.4959677419354839
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# [[], [-1]]
# 0.5
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[-0.00704709 -0.00988792 -0.00801853 ...  0.          0.
#   0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# Loaded the voice encoder model on cpu in 0.02 seconds.
# [['new_audio[0, 0.86].wav', 'new_audio[0.86, 0.86].wav'], [('0', 0, 0.86), ('1', 0.86, 0.86)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# Erreur
# 0.5040322580645161
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[-0.04454038 -0.0692761  -0.05289915 ...  0.          0.
#   0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.04].wav', 'new_audio[1.04, 1.1].wav', 'new_audio[1.1, 1.22].wav', 'new_audio[1.22, 1.4].wav', 'new_audio[1.4, 1.58].wav', 'new_audio[1.58, 1.7].wav', 'new_audio[1.7, 1.82].wav', 'new_audio[1.82, 1.88].wav', 'new_audio[1.88, 1.94].wav', 'new_audio[1.94, 2.42].wav', 'new_audio[2.42, 2.48].wav', 'new_audio[2.48, 2.54].wav', 'new_audio[2.54, 2.66].wav', 'new_audio[2.66, 2.72].wav', 'new_audio[2.72, 2.78].wav', 'new_audio[2.78, 2.84].wav', 'new_audio[2.84, 2.96].wav', 'new_audio[2.96, 3.08].wav', 'new_audio[3.08, 3.08].wav'], [('0', 0, 1.04), ('11', 1.04, 1.1), ('4', 1.1, 1.22), ('6', 1.22, 1.4), ('7', 1.4, 1.58), ('12', 1.58, 1.7), ('8', 1.7, 1.82), ('15', 1.82, 1.88), ('14', 1.88, 1.94), ('1', 1.94, 2.42), ('18', 2.42, 2.48), ('17', 2.48, 2.54), ('9', 2.54, 2.66), ('16', 2.66, 2.72), ('13', 2.72, 2.78), ('10', 2.78, 2.84), ('3', 2.84, 2.96), ('2', 2.96, 3.08), ('5', 3.08, 3.08)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# Erreur
# 0.5080645161290323
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0.04937275 0.07575369 0.07245471 ... 0.         0.         0.        ], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.18].wav', 'new_audio[2.18, 3.44].wav'], [('1', 0, 2.18), ('0', 2.18, 3.44)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.5120967741935484
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# ...
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=24000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 1.94].wav', 'new_audio[1.94, 3.68].wav', 'new_audio[3.68, 5.54].wav', 'new_audio[5.54, 7.1].wav', 'new_audio[7.1, 7.88].wav'], [('3', 0, 1.94), ('1', 1.94, 3.68), ('0', 3.68, 5.54), ('2', 5.54, 7.1), ('4', 7.1, 7.88)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.9838709677419355
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=24000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.12].wav', 'new_audio[2.12, 2.78].wav', 'new_audio[2.78, 3.74].wav', 'new_audio[3.74, 5.66].wav'], [('1', 0, 2.12), ('0', 2.12, 2.78), ('1', 2.78, 3.74), ('0', 3.74, 5.66)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.9879032258064516
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:33: FutureWarning: Pass orig_sr=24000, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav = librosa.resample(wav, source_sr, sampling_rate)
# Loaded the voice encoder model on cpu in 0.02 seconds.
# C:\Users\Paul\anaconda3\lib\site-packages\resemblyzer\audio.py:47: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   frames = librosa.feature.melspectrogram(
# [['new_audio[0, 2.0].wav', 'new_audio[2.0, 2.66].wav', 'new_audio[2.66, 4.1].wav', 'new_audio[4.1, 5.42].wav', 'new_audio[5.42, 6.5].wav', 'new_audio[6.5, 7.76].wav', 'new_audio[7.76, 8.78].wav', 'new_audio[8.78, 9.8].wav'], [('4', 0, 2.0), ('6', 2.0, 2.66), ('3', 2.66, 4.1), ('2', 4.1, 5.42), ('7', 5.42, 6.5), ('1', 6.5, 7.76), ('0', 7.76, 8.78), ('5', 8.78, 9.8)]]
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\Paul\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# 0.9919354838709677
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\pyannote\algorithms\utils\viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# C:\Users\Paul\anaconda3\lib\site-packages\inaSpeechSegmenter\segmenter.py:61: RuntimeWarning: invalid value encountered in subtract
#   data = (data - np.mean(data, axis=1).reshape((len(data), 1))) / np.std(data, axis=1).reshape((len(data), 1))
# C:\Users\Paul\anaconda3\lib\site-packages\numpy\core\_methods.py:229: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# [[], [-1]]
# 0.9959677419354839

# %%
res3
# Out:
# {'3344': {'M': 0, 'F': 5},
#  '3362': {'M': 2, 'F': 26},
#  '3377': {'M': 2, 'F': 0},
#  '3382': {'M': 2, 'F': 0},
#  '339': {'M': 0, 'F': 0},
#  '3423': {'M': 1, 'F': 1},
#  '3454': {'M': 1, 'F': 1},
#  '3480': {'M': 0, 'F': 3},
#  '3484': {'M': 0, 'F': 9},
#  '3487': {'M': 4, 'F': 7},
#  '3492': {'M': 0, 'F': 2},
#  '3494': {'M': 1, 'F': 2},
#  '3500': {'M': 2, 'F': 0},
#  '3508': {'M': 2, 'F': 1},
#  '3513': {'M': 2, 'F': 26},
#  '3520': {'M': 0, 'F': 2},
#  '3534': {'M': 4, 'F': 2},
#  '3549': {'M': 4, 'F': 4},
#  '3580': {'M': 0, 'F': 2},
#  '360': {'M': 1, 'F': 1},
#  '3604': {'M': 7, 'F': 11},
#  '3609': {'M': 0, 'F': 2},
#  '3610': {'M': 0, 'F': 0},
#  '3630': {'M': 0, 'F': 2},
#  '3631': {'M': 4, 'F': 1},
#  '3647': {'M': 5, 'F': 0},
#  '3651': {'M': 7, 'F': 0},
#  '3655': {'M': 0, 'F': 0},
#  '366': {'M': 0, 'F': 0},
#  '3667': {'M': 1, 'F': 1},
#  '3716': {'M': 0, 'F': 0},
#  '3721': {'M': 0, 'F': 0},
#  '3762': {'M': 0, 'F': 0},
#  '3794': {'M': 2, 'F': 20},
#  '38': {'M': 0, 'F': 0},
#  '383': {'M': 1, 'F': 6},
#  '3882': {'M': 0, 'F': 4},
#  '3899': {'M': 4, 'F': 3},
#  '3911': {'M': 0, 'F': 18},
#  '3917': {'M': 2, 'F': 0},
#  '3924': {'M': 4, 'F': 5},
#  '3976': {'M': 4, 'F': 1},
#  '398': {'M': 0, 'F': 0},
#  '3991': {'M': 0, 'F': 2},
#  '3992': {'M': 3, 'F': 7},
#  '401': {'M': 1, 'F': 12},
#  '403': {'M': 0, 'F': 0},
#  '4046': {'M': 0, 'F': 4},
#  '407': {'M': 0, 'F': 0},
#  '4086': {'M': 3, 'F': 3},
#  '4090': {'M': 3, 'F': 5},
#  '4102': {'M': 6, 'F': 2},
#  '4104': {'M': 2, 'F': 1},
#  '4182': {'M': 0, 'F': 0},
#  '4187': {'M': 0, 'F': 0},
#  '4190': {'M': 0, 'F': 0},
#  '4222': {'M': 0, 'F': 2},
#  '4243': {'M': 2, 'F': 6},
#  '4244': {'M': 2, 'F': 10},
#  '4249': {'M': 0, 'F': 0},
#  '4252': {'M': 1, 'F': 1},
#  '4259': {'M': 0, 'F': 3},
#  '4266': {'M': 3, 'F': 6},
#  '4283': {'M': 0, 'F': 0},
#  '4295': {'M': 3, 'F': 2},
#  '4301': {'M': 2, 'F': 1},
#  '4305': {'M': 1, 'F': 1},
#  '4310': {'M': 0, 'F': 2},
#  '4312': {'M': 0, 'F': 0},
#  '4357': {'M': 2, 'F': 2},
#  '4422': {'M': 0, 'F': 2},
#  '4429': {'M': 1, 'F': 5},
#  '4438': {'M': 0, 'F': 2},
#  '4445': {'M': 2, 'F': 5},
#  '45': {'M': 0, 'F': 0},
#  '451': {'M': 0, 'F': 0},
#  '463': {'M': 0, 'F': 0},
#  '47': {'M': 0, 'F': 0},
#  '472': {'M': 0, 'F': 0},
#  '480': {'M': 0, 'F': 0},
#  '53': {'M': 0, 'F': 4},
#  '553': {'M': 1, 'F': 6},
#  '563': {'M': 0, 'F': 0},
#  '564': {'M': 0, 'F': 0},
#  '574': {'M': 0, 'F': 0},
#  '586': {'M': 0, 'F': 0},
#  '587': {'M': 0, 'F': 0},
#  '594': {'M': 0, 'F': 0},
#  '599': {'M': 0, 'F': 0},
#  '612': {'M': 1, 'F': 2},
#  '622': {'M': 0, 'F': 0},
#  '673': {'M': 0, 'F': 0},
#  '677': {'M': 0, 'F': 0},
#  '681': {'M': 0, 'F': 0},
#  '702': {'M': 0, 'F': 0},
#  '703': {'M': 0, 'F': 0},
#  '713': {'M': 0, 'F': 0},
#  '724': {'M': 0, 'F': 0},
#  '732': {'M': 0, 'F': 0},
#  '740': {'M': 0, 'F': 0},
#  '752': {'M': 2, 'F': 5},
#  '756': {'M': 1, 'F': 24},
#  '76': {'M': 0, 'F': 0},
#  '762': {'M': 0, 'F': 0},
#  '765': {'M': 5, 'F': 1},
#  '777': {'M': 0, 'F': 0},
#  '803': {'M': 2, 'F': 1},
#  '812': {'M': 0, 'F': 0},
#  '849': {'M': 6, 'F': 4},
#  '85': {'M': 0, 'F': 0},
#  '863': {'M': 12, 'F': 0},
#  '873': {'M': 7, 'F': 4},
#  '875': {'M': 3, 'F': 6},
#  '900': {'M': 2, 'F': 4},
#  '905': {'M': 0, 'F': 0},
#  '906': {'M': 1, 'F': 13},
#  '915': {'M': 1, 'F': 1},
#  '918': {'M': 2, 'F': 2},
#  '942': {'M': 0, 'F': 2},
#  '956': {'M': 3, 'F': 2},
#  '957': {'M': 0, 'F': 4},
#  '959': {'M': 8, 'F': 0},
#  '973': {'M': 0, 'F': 0}}

# %%
final={**res3, **Def_1}

# %%
tab=pd.DataFrame(final).to_csv('Equipe 2 - Résultats-2.csv',';')
